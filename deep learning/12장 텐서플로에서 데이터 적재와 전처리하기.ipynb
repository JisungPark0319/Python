# %%
import tensorflow as tf
import numpy as np

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-33bb777f92b3> in <module>()
#       1 embedding_dim = 2
# ----> 2 embed_init = tf.random.uniform([len(vocab) + num_oov_buckets, embedding_dim])
#
# NameError: name 'vocab' is not defined
